# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.8.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.7 MB/s
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.5.0)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0.dev2021032900)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.37.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.34.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.34.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (57.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.5.0)
# Installing collected packages: tensorflowjs
# Successfully installed tensorflowjs-3.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import zipfile as zip
import glob
from sklearn.model_selection import train_test_split
import os as os
import shutil

# %%
zip_path = "/content/drive/MyDrive/Train-Test/"

# %%
with zip.ZipFile(zip_path + 'train.zip', 'r') as zipObj:
   zipObj.extractall()
  
with zip.ZipFile(zip_path + 'test1.zip', 'r') as zipObj:
   zipObj.extractall()

# %%
test_imgpath = "/content/test1/"
train_imgpath = "/content/train/"

# %%
train_list = glob.glob(os.path.join(train_imgpath,'*.jpg'))
test_list = glob.glob(os.path.join(test_imgpath, '*.jpg'))

# %%
print(len(train_list),len(test_list))
# Out:
# 25000 12500

# %%
train_list, val_list = train_test_split(train_list, test_size=0.2,shuffle=True)

# %%
print(len(train_list),len(val_list))
# Out:
# 20000 5000

# %%
val_list
# Out:
# ['/content/train/dog.10070.jpg',
#  '/content/train/dog.10951.jpg',
#  '/content/train/dog.5845.jpg',
#  '/content/train/cat.8700.jpg',
#  '/content/train/dog.3207.jpg',
#  '/content/train/cat.3176.jpg',
#  '/content/train/dog.5262.jpg',
#  '/content/train/dog.9481.jpg',
#  '/content/train/cat.3162.jpg',
#  '/content/train/dog.9394.jpg',
#  '/content/train/dog.10034.jpg',
#  '/content/train/dog.2213.jpg',
#  '/content/train/cat.3149.jpg',
#  '/content/train/dog.4137.jpg',
#  '/content/train/cat.5355.jpg',
#  '/content/train/cat.4899.jpg',
#  '/content/train/cat.905.jpg',
#  '/content/train/cat.6617.jpg',
#  '/content/train/cat.7661.jpg',
#  '/content/train/dog.10095.jpg',
#  '/content/train/cat.4894.jpg',
#  '/content/train/cat.11313.jpg',
#  '/content/train/cat.3631.jpg',
#  '/content/train/dog.9354.jpg',
#  '/content/train/cat.10508.jpg',
#  '/content/train/dog.6540.jpg',
#  '/content/train/cat.7896.jpg',
#  '/content/train/dog.4679.jpg',
#  '/content/train/cat.4102.jpg',
#  '/content/train/cat.7380.jpg',
#  '/content/train/cat.953.jpg',
#  '/content/train/dog.9448.jpg',
#  '/content/train/dog.1500.jpg',
#  '/content/train/cat.1081.jpg',
#  '/content/train/cat.11298.jpg',
#  '/content/train/dog.1245.jpg',
#  '/content/train/dog.11190.jpg',
#  '/content/train/cat.3258.jpg',
#  '/content/train/dog.8769.jpg',
#  '/content/train/dog.12057.jpg',
#  '/content/train/dog.3036.jpg',
#  '/content/train/cat.5580.jpg',
#  '/content/train/dog.9384.jpg',
#  '/content/train/dog.8080.jpg',
#  '/content/train/dog.672.jpg',
#  '/content/train/dog.3301.jpg',
#  '/content/train/dog.2538.jpg',
#  '/content/train/dog.7781.jpg',
#  '/content/train/dog.12157.jpg',
#  '/content/train/cat.3000.jpg',
#  '/content/train/dog.6156.jpg',
#  '/content/train/cat.5294.jpg',
#  '/content/train/cat.10072.jpg',
#  '/content/train/cat.7630.jpg',
#  '/content/train/cat.3516.jpg',
#  '/content/train/dog.678.jpg',
#  '/content/train/cat.7097.jpg',
#  '/content/train/dog.9705.jpg',
#  '/content/train/cat.8355.jpg',
#  '/content/train/dog.1139.jpg',
#  '/content/train/cat.2659.jpg',
#  '/content/train/dog.1552.jpg',
#  '/content/train/cat.9330.jpg',
#  '/content/train/cat.8468.jpg',
#  '/content/train/cat.6970.jpg',
#  '/content/train/cat.4187.jpg',
#  '/content/train/dog.7672.jpg',
#  '/content/train/cat.2630.jpg',
#  '/content/train/dog.2759.jpg',
#  '/content/train/dog.7362.jpg',
#  '/content/train/cat.2212.jpg',
#  '/content/train/dog.1729.jpg',
#  '/content/train/dog.3019.jpg',
#  '/content/train/dog.11476.jpg',
#  '/content/train/dog.3144.jpg',
#  '/content/train/dog.24.jpg',
#  '/content/train/dog.4502.jpg',
#  '/content/train/cat.4631.jpg',
#  '/content/train/dog.5068.jpg',
#  '/content/train/dog.10600.jpg',
#  '/content/train/dog.3187.jpg',
#  '/content/train/dog.5210.jpg',
#  '/content/train/dog.3302.jpg',
#  '/content/train/dog.8540.jpg',
#  '/content/train/cat.12269.jpg',
#  '/content/train/dog.10366.jpg',
#  '/content/train/cat.7825.jpg',
#  '/content/train/dog.2527.jpg',
#  '/content/train/cat.5431.jpg',
#  '/content/train/dog.128.jpg',
#  '/content/train/cat.6238.jpg',
#  '/content/train/cat.1894.jpg',
#  '/content/train/dog.4812.jpg',
#  '/content/train/cat.7462.jpg',
#  '/content/train/cat.3530.jpg',
#  '/content/train/dog.11916.jpg',
#  '/content/train/cat.2948.jpg',
#  '/content/train/cat.2766.jpg',
#  '/content/train/cat.9367.jpg',
#  '/content/train/cat.7595.jpg',
#  '/content/train/cat.6158.jpg',
#  '/content/train/dog.8987.jpg',
#  '/content/train/cat.9299.jpg',
#  '/content/train/dog.1958.jpg',
#  '/content/train/cat.4469.jpg',
#  '/content/train/cat.5790.jpg',
#  '/content/train/dog.11892.jpg',
#  '/content/train/cat.3374.jpg',
#  '/content/train/dog.4714.jpg',
#  '/content/train/dog.8366.jpg',
#  '/content/train/dog.1427.jpg',
#  '/content/train/dog.2414.jpg',
#  '/content/train/cat.4251.jpg',
#  '/content/train/cat.10968.jpg',
#  '/content/train/cat.12349.jpg',
#  '/content/train/cat.8851.jpg',
#  '/content/train/dog.5782.jpg',
#  '/content/train/dog.4440.jpg',
#  '/content/train/dog.11929.jpg',
#  '/content/train/dog.6046.jpg',
#  '/content/train/cat.7894.jpg',
#  '/content/train/cat.1371.jpg',
#  '/content/train/cat.5526.jpg',
#  '/content/train/dog.414.jpg',
#  '/content/train/dog.11366.jpg',
#  '/content/train/dog.10900.jpg',
#  '/content/train/dog.6582.jpg',
#  '/content/train/dog.3316.jpg',
#  '/content/train/dog.8119.jpg',
#  '/content/train/cat.6542.jpg',
#  '/content/train/dog.2586.jpg',
#  '/content/train/cat.10869.jpg',
#  '/content/train/dog.10136.jpg',
#  '/content/train/dog.3882.jpg',
#  '/content/train/cat.4240.jpg',
#  '/content/train/dog.10594.jpg',
#  '/content/train/dog.690.jpg',
#  '/content/train/dog.10272.jpg',
#  '/content/train/dog.1055.jpg',
#  '/content/train/cat.10901.jpg',
#  '/content/train/dog.3055.jpg',
#  '/content/train/dog.9292.jpg',
#  '/content/train/cat.8012.jpg',
#  '/content/train/dog.3881.jpg',
#  '/content/train/cat.7029.jpg',
#  '/content/train/dog.2211.jpg',
#  '/content/train/cat.7664.jpg',
#  '/content/train/cat.2909.jpg',
#  '/content/train/cat.3718.jpg',
#  '/content/train/dog.10705.jpg',
#  '/content/train/dog.12206.jpg',
#  '/content/train/cat.297.jpg',
#  '/content/train/dog.3395.jpg',
#  '/content/train/dog.9784.jpg',
#  '/content/train/dog.4971.jpg',
#  '/content/train/cat.6656.jpg',
#  '/content/train/dog.5645.jpg',
#  '/content/train/dog.11369.jpg',
#  '/content/train/dog.3365.jpg',
#  '/content/train/dog.7803.jpg',
#  '/content/train/cat.331.jpg',
#  '/content/train/cat.4260.jpg',
#  '/content/train/dog.9372.jpg',
#  '/content/train/dog.5864.jpg',
#  '/content/train/dog.148.jpg',
#  '/content/train/cat.1760.jpg',
#  '/content/train/dog.7987.jpg',
#  '/content/train/dog.7867.jpg',
#  '/content/train/cat.11951.jpg',
#  '/content/train/cat.776.jpg',
#  '/content/train/cat.3407.jpg',
#  '/content/train/cat.9705.jpg',
#  '/content/train/dog.627.jpg',
#  '/content/train/dog.12233.jpg',
#  '/content/train/dog.2910.jpg',
#  '/content/train/cat.1957.jpg',
#  '/content/train/dog.184.jpg',
#  '/content/train/cat.7823.jpg',
#  '/content/train/dog.5432.jpg',
#  '/content/train/cat.6278.jpg',
#  '/content/train/dog.5635.jpg',
#  '/content/train/dog.9646.jpg',
#  '/content/train/dog.8299.jpg',
#  '/content/train/dog.9766.jpg',
#  '/content/train/dog.2727.jpg',
#  '/content/train/cat.10981.jpg',
#  '/content/train/dog.12092.jpg',
#  '/content/train/cat.6836.jpg',
#  '/content/train/cat.11714.jpg',
#  '/content/train/dog.8909.jpg',
#  '/content/train/dog.1949.jpg',
#  '/content/train/cat.1065.jpg',
#  '/content/train/dog.3343.jpg',
#  '/content/train/dog.11399.jpg',
#  '/content/train/cat.2382.jpg',
#  '/content/train/dog.5753.jpg',
#  '/content/train/cat.5387.jpg',
#  '/content/train/cat.4121.jpg',
#  '/content/train/cat.7109.jpg',
#  '/content/train/dog.7509.jpg',
#  '/content/train/dog.5073.jpg',
#  '/content/train/dog.3230.jpg',
#  '/content/train/cat.7768.jpg',
#  '/content/train/cat.3523.jpg',
#  '/content/train/dog.7955.jpg',
#  '/content/train/dog.3170.jpg',
#  '/content/train/dog.12044.jpg',
#  '/content/train/dog.12332.jpg',
#  '/content/train/dog.11889.jpg',
#  '/content/train/cat.12450.jpg',
#  '/content/train/cat.5835.jpg',
#  '/content/train/dog.6391.jpg',
#  '/content/train/cat.10406.jpg',
#  '/content/train/dog.2748.jpg',
#  '/content/train/cat.6399.jpg',
#  '/content/train/cat.12074.jpg',
#  '/content/train/dog.10569.jpg',
#  '/content/train/dog.3336.jpg',
#  '/content/train/cat.12169.jpg',
#  '/content/train/dog.908.jpg',
#  '/content/train/cat.5527.jpg',
#  '/content/train/cat.281.jpg',
#  '/content/train/dog.11271.jpg',
#  '/content/train/cat.9090.jpg',
#  '/content/train/cat.10318.jpg',
#  '/content/train/dog.2575.jpg',
#  '/content/train/dog.11588.jpg',
#  '/content/train/dog.1326.jpg',
#  '/content/train/cat.142.jpg',
#  '/content/train/dog.7007.jpg',
#  '/content/train/cat.8269.jpg',
#  '/content/train/dog.8009.jpg',
#  '/content/train/cat.4299.jpg',
#  '/content/train/cat.1848.jpg',
#  '/content/train/cat.1714.jpg',
#  '/content/train/dog.10307.jpg',
#  '/content/train/dog.8754.jpg',
#  '/content/train/dog.3136.jpg',
#  '/content/train/dog.4391.jpg',
#  '/content/train/dog.376.jpg',
#  '/content/train/cat.11213.jpg',
#  '/content/train/cat.2783.jpg',
#  '/content/train/cat.961.jpg',
#  '/content/train/dog.7467.jpg',
#  '/content/train/dog.6865.jpg',
#  '/content/train/cat.2794.jpg',
#  '/content/train/dog.2122.jpg',
#  '/content/train/cat.9121.jpg',
#  '/content/train/cat.5900.jpg',
#  '/content/train/cat.5239.jpg',
#  '/content/train/dog.3132.jpg',
#  '/content/train/cat.12492.jpg',
#  '/content/train/dog.12072.jpg',
#  '/content/train/cat.2914.jpg',
#  '/content/train/cat.9481.jpg',
#  '/content/train/cat.975.jpg',
#  '/content/train/cat.9693.jpg',
#  '/content/train/cat.7205.jpg',
#  '/content/train/cat.7868.jpg',
#  '/content/train/dog.8873.jpg',
#  '/content/train/dog.7179.jpg',
#  '/content/train/dog.9291.jpg',
#  '/content/train/dog.7218.jpg',
#  '/content/train/dog.1384.jpg',
#  '/content/train/cat.2406.jpg',
#  '/content/train/cat.8849.jpg',
#  '/content/train/cat.2878.jpg',
#  '/content/train/dog.8229.jpg',
#  '/content/train/dog.12186.jpg',
#  '/content/train/cat.12194.jpg',
#  '/content/train/cat.9339.jpg',
#  '/content/train/dog.9941.jpg',
#  '/content/train/cat.8844.jpg',
#  '/content/train/dog.10637.jpg',
#  '/content/train/dog.4106.jpg',
#  '/content/train/dog.7931.jpg',
#  '/content/train/cat.4338.jpg',
#  '/content/train/dog.8524.jpg',
#  '/content/train/cat.2619.jpg',
#  '/content/train/dog.2991.jpg',
#  '/content/train/cat.9600.jpg',
#  '/content/train/dog.6246.jpg',
#  '/content/train/cat.2352.jpg',
#  '/content/train/cat.9609.jpg',
#  '/content/train/dog.3561.jpg',
#  '/content/train/cat.3461.jpg',
#  '/content/train/dog.2244.jpg',
#  '/content/train/cat.9461.jpg',
#  '/content/train/cat.5671.jpg',
#  '/content/train/cat.681.jpg',
#  '/content/train/dog.11039.jpg',
#  '/content/train/dog.12171.jpg',
#  '/content/train/cat.4663.jpg',
#  '/content/train/dog.11530.jpg',
#  '/content/train/dog.6252.jpg',
#  '/content/train/dog.11269.jpg',
#  '/content/train/dog.10076.jpg',
#  '/content/train/dog.5948.jpg',
#  '/content/train/cat.6930.jpg',
#  '/content/train/cat.2996.jpg',
#  '/content/train/cat.130.jpg',
#  '/content/train/cat.246.jpg',
#  '/content/train/cat.6931.jpg',
#  '/content/train/dog.10668.jpg',
#  '/content/train/dog.10971.jpg',
#  '/content/train/cat.1263.jpg',
#  '/content/train/dog.326.jpg',
#  '/content/train/cat.2241.jpg',
#  '/content/train/cat.455.jpg',
#  '/content/train/cat.5587.jpg',
#  '/content/train/cat.6705.jpg',
#  '/content/train/dog.4059.jpg',
#  '/content/train/dog.2887.jpg',
#  '/content/train/cat.4665.jpg',
#  '/content/train/dog.3787.jpg',
#  '/content/train/dog.11417.jpg',
#  '/content/train/dog.8529.jpg',
#  '/content/train/dog.2487.jpg',
#  '/content/train/cat.8915.jpg',
#  '/content/train/dog.7016.jpg',
#  '/content/train/dog.12327.jpg',
#  '/content/train/dog.116.jpg',
#  '/content/train/dog.12496.jpg',
#  '/content/train/dog.87.jpg',
#  '/content/train/dog.3024.jpg',
#  '/content/train/cat.942.jpg',
#  '/content/train/cat.1802.jpg',
#  '/content/train/cat.6449.jpg',
#  '/content/train/dog.8546.jpg',
#  '/content/train/dog.7533.jpg',
#  '/content/train/dog.4561.jpg',
#  '/content/train/cat.9385.jpg',
#  '/content/train/dog.9812.jpg',
#  '/content/train/cat.11027.jpg',
#  '/content/train/cat.238.jpg',
#  '/content/train/dog.4389.jpg',
#  '/content/train/cat.8463.jpg',
#  '/content/train/cat.4683.jpg',
#  '/content/train/cat.1963.jpg',
#  '/content/train/cat.2661.jpg',
#  '/content/train/cat.9534.jpg',
#  '/content/train/dog.10652.jpg',
#  '/content/train/dog.8815.jpg',
#  '/content/train/cat.464.jpg',
#  '/content/train/cat.12012.jpg',
#  '/content/train/cat.4502.jpg',
#  '/content/train/dog.11223.jpg',
#  '/content/train/cat.424.jpg',
#  '/content/train/dog.2207.jpg',
#  '/content/train/dog.3788.jpg',
#  '/content/train/cat.10217.jpg',
#  '/content/train/dog.6700.jpg',
#  '/content/train/dog.2602.jpg',
#  '/content/train/dog.8210.jpg',
#  '/content/train/cat.2176.jpg',
#  '/content/train/dog.1506.jpg',
#  '/content/train/dog.602.jpg',
#  '/content/train/dog.10922.jpg',
#  '/content/train/dog.9301.jpg',
#  '/content/train/cat.9701.jpg',
#  '/content/train/cat.5152.jpg',
#  '/content/train/cat.1040.jpg',
#  '/content/train/cat.2413.jpg',
#  '/content/train/cat.5669.jpg',
#  '/content/train/cat.3668.jpg',
#  '/content/train/cat.1630.jpg',
#  '/content/train/dog.5027.jpg',
#  '/content/train/cat.6135.jpg',
#  '/content/train/dog.1281.jpg',
#  '/content/train/cat.2470.jpg',
#  '/content/train/dog.3028.jpg',
#  '/content/train/cat.3019.jpg',
#  '/content/train/dog.1390.jpg',
#  '/content/train/dog.4485.jpg',
#  '/content/train/cat.10880.jpg',
#  '/content/train/dog.9324.jpg',
#  '/content/train/dog.7106.jpg',
#  '/content/train/cat.6005.jpg',
#  '/content/train/dog.5463.jpg',
#  '/content/train/dog.10185.jpg',
#  '/content/train/dog.4078.jpg',
#  '/content/train/dog.1380.jpg',
#  '/content/train/cat.7132.jpg',
#  '/content/train/cat.2890.jpg',
#  '/content/train/cat.12211.jpg',
#  '/content/train/cat.10676.jpg',
#  '/content/train/cat.5.jpg',
#  '/content/train/cat.12223.jpg',
#  '/content/train/dog.1787.jpg',
#  '/content/train/dog.757.jpg',
#  '/content/train/dog.3982.jpg',
#  '/content/train/dog.8476.jpg',
#  '/content/train/dog.10943.jpg',
#  '/content/train/dog.4095.jpg',
#  '/content/train/dog.7913.jpg',
#  '/content/train/cat.9352.jpg',
#  '/content/train/cat.1316.jpg',
#  '/content/train/dog.3961.jpg',
#  '/content/train/dog.2510.jpg',
#  '/content/train/cat.5976.jpg',
#  '/content/train/dog.4353.jpg',
#  '/content/train/cat.8172.jpg',
#  '/content/train/dog.3944.jpg',
#  '/content/train/cat.2628.jpg',
#  '/content/train/dog.7452.jpg',
#  '/content/train/dog.9701.jpg',
#  '/content/train/cat.2200.jpg',
#  '/content/train/cat.4645.jpg',
#  '/content/train/dog.5426.jpg',
#  '/content/train/cat.4361.jpg',
#  '/content/train/cat.4462.jpg',
#  '/content/train/dog.8278.jpg',
#  '/content/train/cat.7403.jpg',
#  '/content/train/cat.9946.jpg',
#  '/content/train/dog.11753.jpg',
#  '/content/train/cat.6802.jpg',
#  '/content/train/cat.6613.jpg',
#  '/content/train/dog.10279.jpg',
#  '/content/train/dog.5177.jpg',
#  '/content/train/dog.4287.jpg',
#  '/content/train/dog.6450.jpg',
#  '/content/train/cat.4599.jpg',
#  '/content/train/dog.6416.jpg',
#  '/content/train/cat.9061.jpg',
#  '/content/train/cat.8604.jpg',
#  '/content/train/cat.1444.jpg',
#  '/content/train/cat.10636.jpg',
#  '/content/train/cat.11369.jpg',
#  '/content/train/dog.9087.jpg',
#  '/content/train/dog.12429.jpg',
#  '/content/train/dog.3878.jpg',
#  '/content/train/dog.7530.jpg',
#  '/content/train/cat.7180.jpg',
#  '/content/train/cat.7301.jpg',
#  '/content/train/dog.6608.jpg',
#  '/content/train/cat.1771.jpg',
#  '/content/train/dog.6998.jpg',
#  '/content/train/dog.6238.jpg',
#  '/content/train/dog.4690.jpg',
#  '/content/train/dog.10544.jpg',
#  '/content/train/cat.8643.jpg',
#  '/content/train/dog.9901.jpg',
#  '/content/train/dog.12436.jpg',
#  '/content/train/dog.1072.jpg',
#  '/content/train/cat.2089.jpg',
#  '/content/train/dog.3498.jpg',
#  '/content/train/cat.8699.jpg',
#  '/content/train/cat.8778.jpg',
#  '/content/train/cat.6192.jpg',
#  '/content/train/cat.6208.jpg',
#  '/content/train/dog.2367.jpg',
#  '/content/train/dog.4646.jpg',
#  '/content/train/dog.6532.jpg',
#  '/content/train/dog.3198.jpg',
#  '/content/train/cat.3955.jpg',
#  '/content/train/dog.1230.jpg',
#  '/content/train/cat.7065.jpg',
#  '/content/train/dog.7015.jpg',
#  '/content/train/cat.4242.jpg',
#  '/content/train/dog.5160.jpg',
#  '/content/train/cat.4836.jpg',
#  '/content/train/cat.11933.jpg',
#  '/content/train/dog.7411.jpg',
#  '/content/train/dog.2685.jpg',
#  '/content/train/dog.2327.jpg',
#  '/content/train/cat.12031.jpg',
#  '/content/train/dog.6574.jpg',
#  '/content/train/cat.2693.jpg',
#  '/content/train/dog.5687.jpg',
#  '/content/train/dog.1836.jpg',
#  '/content/train/cat.10824.jpg',
#  '/content/train/dog.404.jpg',
#  '/content/train/dog.4949.jpg',
#  '/content/train/cat.10223.jpg',
#  '/content/train/cat.3659.jpg',
#  '/content/train/dog.10387.jpg',
#  '/content/train/dog.1418.jpg',
#  '/content/train/dog.12419.jpg',
#  '/content/train/dog.12131.jpg',
#  '/content/train/cat.756.jpg',
#  '/content/train/dog.243.jpg',
#  '/content/train/dog.7385.jpg',
#  '/content/train/cat.12124.jpg',
#  '/content/train/cat.9216.jpg',
#  '/content/train/cat.1518.jpg',
#  '/content/train/cat.7491.jpg',
#  '/content/train/dog.2130.jpg',
#  '/content/train/dog.12144.jpg',
#  '/content/train/cat.10623.jpg',
#  '/content/train/cat.3448.jpg',
#  '/content/train/cat.11609.jpg',
#  '/content/train/cat.11180.jpg',
#  '/content/train/dog.413.jpg',
#  '/content/train/cat.4782.jpg',
#  '/content/train/cat.6270.jpg',
#  '/content/train/cat.1220.jpg',
#  '/content/train/cat.5984.jpg',
#  '/content/train/dog.3828.jpg',
#  '/content/train/cat.12337.jpg',
#  '/content/train/dog.3546.jpg',
#  '/content/train/cat.8274.jpg',
#  '/content/train/cat.8561.jpg',
#  '/content/train/cat.6798.jpg',
#  '/content/train/cat.1314.jpg',
#  '/content/train/cat.5030.jpg',
#  '/content/train/cat.10494.jpg',
#  '/content/train/dog.5026.jpg',
#  '/content/train/dog.3357.jpg',
#  '/content/train/dog.663.jpg',
#  '/content/train/cat.2023.jpg',
#  '/content/train/dog.2957.jpg',
#  '/content/train/dog.204.jpg',
#  '/content/train/dog.4589.jpg',
#  '/content/train/cat.7593.jpg',
#  '/content/train/cat.6573.jpg',
#  '/content/train/cat.2615.jpg',
#  '/content/train/dog.956.jpg',
#  '/content/train/dog.7455.jpg',
#  '/content/train/dog.8377.jpg',
#  '/content/train/dog.10747.jpg',
#  '/content/train/dog.9924.jpg',
#  '/content/train/dog.6468.jpg',
#  '/content/train/cat.5830.jpg',
#  '/content/train/dog.8706.jpg',
#  '/content/train/dog.6075.jpg',
#  '/content/train/dog.3045.jpg',
#  '/content/train/dog.6441.jpg',
#  '/content/train/cat.6494.jpg',
#  '/content/train/cat.8769.jpg',
#  '/content/train/dog.9225.jpg',
#  '/content/train/cat.2133.jpg',
#  '/content/train/cat.3966.jpg',
#  '/content/train/cat.9673.jpg',
#  '/content/train/dog.4778.jpg',
#  '/content/train/cat.4202.jpg',
#  '/content/train/dog.9657.jpg',
#  '/content/train/dog.5015.jpg',
#  '/content/train/dog.4359.jpg',
#  '/content/train/cat.7705.jpg',
#  '/content/train/dog.12395.jpg',
#  '/content/train/cat.2995.jpg',
#  '/content/train/cat.2468.jpg',
#  '/content/train/dog.10373.jpg',
#  '/content/train/dog.7907.jpg',
#  '/content/train/dog.2071.jpg',
#  '/content/train/dog.5856.jpg',
#  '/content/train/dog.1000.jpg',
#  '/content/train/cat.3779.jpg',
#  '/content/train/dog.12008.jpg',
#  '/content/train/cat.293.jpg',
#  '/content/train/cat.7637.jpg',
#  '/content/train/dog.2058.jpg',
#  '/content/train/dog.3653.jpg',
#  '/content/train/dog.1553.jpg',
#  '/content/train/cat.911.jpg',
#  '/content/train/cat.7511.jpg',
#  '/content/train/dog.9170.jpg',
#  '/content/train/dog.4294.jpg',
#  '/content/train/dog.9434.jpg',
#  '/content/train/dog.10437.jpg',
#  '/content/train/dog.8458.jpg',
#  '/content/train/dog.10262.jpg',
#  '/content/train/cat.9592.jpg',
#  '/content/train/dog.5777.jpg',
#  '/content/train/dog.2436.jpg',
#  '/content/train/cat.11901.jpg',
#  '/content/train/cat.2017.jpg',
#  '/content/train/cat.9635.jpg',
#  '/content/train/dog.3087.jpg',
#  '/content/train/cat.2316.jpg',
#  '/content/train/dog.3414.jpg',
#  '/content/train/cat.4016.jpg',
#  '/content/train/dog.6056.jpg',
#  '/content/train/cat.10181.jpg',
#  '/content/train/cat.4130.jpg',
#  '/content/train/dog.3241.jpg',
#  '/content/train/dog.11982.jpg',
#  '/content/train/cat.11830.jpg',
#  '/content/train/dog.10504.jpg',
#  '/content/train/cat.11701.jpg',
#  '/content/train/cat.2105.jpg',
#  '/content/train/dog.8809.jpg',
#  '/content/train/dog.2672.jpg',
#  '/content/train/dog.2494.jpg',
#  '/content/train/cat.4344.jpg',
#  '/content/train/dog.12158.jpg',
#  '/content/train/dog.7647.jpg',
#  '/content/train/cat.8004.jpg',
#  '/content/train/cat.7037.jpg',
#  '/content/train/cat.9244.jpg',
#  '/content/train/cat.2129.jpg',
#  '/content/train/cat.3324.jpg',
#  '/content/train/dog.10598.jpg',
#  '/content/train/cat.2892.jpg',
#  '/content/train/cat.11970.jpg',
#  '/content/train/dog.7008.jpg',
#  '/content/train/cat.7316.jpg',
#  '/content/train/cat.220.jpg',
#  '/content/train/dog.6388.jpg',
#  '/content/train/dog.9743.jpg',
#  '/content/train/cat.11420.jpg',
#  '/content/train/dog.10724.jpg',
#  '/content/train/cat.597.jpg',
#  '/content/train/cat.2467.jpg',
#  '/content/train/dog.12189.jpg',
#  '/content/train/dog.1132.jpg',
#  '/content/train/cat.6035.jpg',
#  '/content/train/cat.3894.jpg',
#  '/content/train/dog.4986.jpg',
#  '/content/train/cat.11165.jpg',
#  '/content/train/dog.996.jpg',
#  '/content/train/dog.7475.jpg',
#  '/content/train/dog.4961.jpg',
#  '/content/train/dog.61.jpg',
#  '/content/train/dog.12015.jpg',
#  '/content/train/cat.1369.jpg',
#  '/content/train/cat.10035.jpg',
#  '/content/train/dog.4206.jpg',
#  '/content/train/dog.7944.jpg',
#  '/content/train/cat.5602.jpg',
#  '/content/train/dog.1615.jpg',
#  '/content/train/dog.10695.jpg',
#  '/content/train/cat.5693.jpg',
#  '/content/train/cat.10379.jpg',
#  '/content/train/cat.7332.jpg',
#  '/content/train/dog.6843.jpg',
#  '/content/train/dog.8141.jpg',
#  '/content/train/cat.8800.jpg',
#  '/content/train/cat.4032.jpg',
#  '/content/train/dog.2771.jpg',
#  '/content/train/cat.11475.jpg',
#  '/content/train/dog.723.jpg',
#  '/content/train/cat.9332.jpg',
#  '/content/train/cat.3469.jpg',
#  '/content/train/dog.9867.jpg',
#  '/content/train/cat.9887.jpg',
#  '/content/train/dog.6098.jpg',
#  '/content/train/cat.10912.jpg',
#  '/content/train/cat.4017.jpg',
#  '/content/train/dog.6604.jpg',
#  '/content/train/dog.8132.jpg',
#  '/content/train/dog.2374.jpg',
#  '/content/train/dog.11687.jpg',
#  '/content/train/cat.4863.jpg',
#  '/content/train/cat.677.jpg',
#  '/content/train/dog.7895.jpg',
#  '/content/train/cat.8896.jpg',
#  '/content/train/cat.11454.jpg',
#  '/content/train/dog.8997.jpg',
#  '/content/train/cat.10387.jpg',
#  '/content/train/cat.11063.jpg',
#  '/content/train/cat.3068.jpg',
#  '/content/train/cat.10856.jpg',
#  '/content/train/dog.3782.jpg',
#  '/content/train/cat.1282.jpg',
#  '/content/train/dog.8439.jpg',
#  '/content/train/dog.11011.jpg',
#  '/content/train/cat.441.jpg',
#  '/content/train/dog.10181.jpg',
#  '/content/train/cat.8434.jpg',
#  '/content/train/dog.3639.jpg',
#  '/content/train/dog.6521.jpg',
#  '/content/train/cat.4853.jpg',
#  '/content/train/cat.11022.jpg',
#  '/content/train/dog.5264.jpg',
#  '/content/train/cat.1670.jpg',
#  '/content/train/dog.153.jpg',
#  '/content/train/dog.7851.jpg',
#  '/content/train/dog.2956.jpg',
#  '/content/train/dog.8153.jpg',
#  '/content/train/cat.2782.jpg',
#  '/content/train/dog.7285.jpg',
#  '/content/train/cat.5849.jpg',
#  '/content/train/cat.4037.jpg',
#  '/content/train/cat.8550.jpg',
#  '/content/train/dog.4334.jpg',
#  '/content/train/cat.3218.jpg',
#  '/content/train/dog.744.jpg',
#  '/content/train/cat.12301.jpg',
#  '/content/train/dog.9841.jpg',
#  '/content/train/cat.7158.jpg',
#  '/content/train/dog.8690.jpg',
#  '/content/train/cat.8448.jpg',
#  '/content/train/dog.7965.jpg',
#  '/content/train/cat.4070.jpg',
#  '/content/train/cat.10145.jpg',
#  '/content/train/cat.1458.jpg',
#  '/content/train/cat.9903.jpg',
#  '/content/train/cat.8278.jpg',
#  '/content/train/dog.2492.jpg',
#  '/content/train/cat.6400.jpg',
#  '/content/train/dog.7479.jpg',
#  '/content/train/dog.10241.jpg',
#  '/content/train/cat.9623.jpg',
#  '/content/train/dog.11649.jpg',
#  '/content/train/cat.8345.jpg',
#  '/content/train/dog.9718.jpg',
#  '/content/train/dog.9418.jpg',
#  '/content/train/dog.10175.jpg',
#  '/content/train/cat.8833.jpg',
#  '/content/train/dog.11878.jpg',
#  '/content/train/cat.6948.jpg',
#  '/content/train/cat.5570.jpg',
#  '/content/train/cat.4452.jpg',
#  '/content/train/dog.6807.jpg',
#  '/content/train/cat.9720.jpg',
#  '/content/train/cat.8303.jpg',
#  '/content/train/cat.8426.jpg',
#  '/content/train/dog.7324.jpg',
#  '/content/train/cat.10804.jpg',
#  '/content/train/dog.6918.jpg',
#  '/content/train/dog.9327.jpg',
#  '/content/train/dog.1622.jpg',
#  '/content/train/dog.8149.jpg',
#  '/content/train/dog.12049.jpg',
#  '/content/train/cat.6635.jpg',
#  '/content/train/dog.5134.jpg',
#  '/content/train/dog.5006.jpg',
#  '/content/train/dog.6591.jpg',
#  '/content/train/cat.3261.jpg',
#  '/content/train/dog.687.jpg',
#  '/content/train/dog.847.jpg',
#  '/content/train/cat.1430.jpg',
#  '/content/train/cat.1380.jpg',
#  '/content/train/cat.7051.jpg',
#  '/content/train/cat.11490.jpg',
#  '/content/train/dog.893.jpg',
#  '/content/train/cat.3105.jpg',
#  '/content/train/dog.1570.jpg',
#  '/content/train/cat.6290.jpg',
#  '/content/train/cat.7219.jpg',
#  '/content/train/cat.6228.jpg',
#  '/content/train/cat.2310.jpg',
#  '/content/train/cat.7781.jpg',
#  '/content/train/dog.9342.jpg',
#  '/content/train/cat.9452.jpg',
#  '/content/train/cat.12013.jpg',
#  '/content/train/dog.7052.jpg',
#  '/content/train/dog.8033.jpg',
#  '/content/train/cat.861.jpg',
#  '/content/train/dog.147.jpg',
#  '/content/train/cat.233.jpg',
#  '/content/train/dog.4655.jpg',
#  '/content/train/cat.4105.jpg',
#  '/content/train/cat.6829.jpg',
#  '/content/train/dog.8612.jpg',
#  '/content/train/cat.12192.jpg',
#  '/content/train/dog.735.jpg',
#  '/content/train/dog.11911.jpg',
#  '/content/train/dog.1607.jpg',
#  '/content/train/cat.3012.jpg',
#  '/content/train/cat.12394.jpg',
#  '/content/train/cat.6555.jpg',
#  '/content/train/dog.7862.jpg',
#  '/content/train/cat.968.jpg',
#  '/content/train/cat.10545.jpg',
#  '/content/train/dog.4445.jpg',
#  '/content/train/dog.4443.jpg',
#  '/content/train/dog.11805.jpg',
#  '/content/train/dog.6850.jpg',
#  '/content/train/cat.38.jpg',
#  '/content/train/dog.6970.jpg',
#  '/content/train/cat.6178.jpg',
#  '/content/train/cat.6021.jpg',
#  '/content/train/cat.10199.jpg',
#  '/content/train/dog.10335.jpg',
#  '/content/train/cat.12405.jpg',
#  '/content/train/cat.5889.jpg',
#  '/content/train/cat.2113.jpg',
#  '/content/train/dog.8530.jpg',
#  '/content/train/dog.6973.jpg',
#  '/content/train/cat.2037.jpg',
#  '/content/train/cat.10164.jpg',
#  '/content/train/cat.836.jpg',
#  '/content/train/dog.11966.jpg',
#  '/content/train/dog.8858.jpg',
#  '/content/train/cat.292.jpg',
#  '/content/train/dog.648.jpg',
#  '/content/train/dog.7047.jpg',
#  '/content/train/dog.2972.jpg',
#  '/content/train/cat.5635.jpg',
#  '/content/train/cat.8753.jpg',
#  '/content/train/dog.11266.jpg',
#  '/content/train/dog.10570.jpg',
#  '/content/train/dog.9543.jpg',
#  '/content/train/cat.9411.jpg',
#  '/content/train/cat.4080.jpg',
#  '/content/train/cat.918.jpg',
#  '/content/train/cat.12146.jpg',
#  '/content/train/dog.8702.jpg',
#  '/content/train/dog.7865.jpg',
#  '/content/train/dog.6860.jpg',
#  '/content/train/cat.1268.jpg',
#  '/content/train/cat.8630.jpg',
#  '/content/train/dog.7180.jpg',
#  '/content/train/dog.7317.jpg',
#  '/content/train/dog.8539.jpg',
#  '/content/train/dog.8125.jpg',
#  '/content/train/dog.6257.jpg',
#  '/content/train/dog.10230.jpg',
#  '/content/train/cat.4530.jpg',
#  '/content/train/dog.11445.jpg',
#  '/content/train/dog.793.jpg',
#  '/content/train/dog.4731.jpg',
#  '/content/train/cat.10878.jpg',
#  '/content/train/dog.4990.jpg',
#  '/content/train/cat.4074.jpg',
#  '/content/train/cat.9611.jpg',
#  '/content/train/cat.11943.jpg',
#  '/content/train/cat.3812.jpg',
#  '/content/train/dog.12054.jpg',
#  '/content/train/cat.8465.jpg',
#  '/content/train/dog.5214.jpg',
#  '/content/train/cat.1070.jpg',
#  '/content/train/cat.8174.jpg',
#  '/content/train/cat.5304.jpg',
#  '/content/train/dog.5760.jpg',
#  '/content/train/cat.6129.jpg',
#  '/content/train/dog.2484.jpg',
#  '/content/train/dog.3935.jpg',
#  '/content/train/dog.10851.jpg',
#  '/content/train/cat.5742.jpg',
#  '/content/train/dog.9584.jpg',
#  '/content/train/cat.10331.jpg',
#  '/content/train/cat.211.jpg',
#  '/content/train/cat.11992.jpg',
#  '/content/train/dog.2978.jpg',
#  '/content/train/dog.11178.jpg',
#  '/content/train/cat.9372.jpg',
#  '/content/train/cat.10170.jpg',
#  '/content/train/cat.12306.jpg',
#  '/content/train/dog.9811.jpg',
#  '/content/train/cat.173.jpg',
#  '/content/train/cat.12239.jpg',
#  '/content/train/cat.2340.jpg',
#  '/content/train/dog.2146.jpg',
#  '/content/train/cat.6716.jpg',
#  '/content/train/dog.7125.jpg',
#  '/content/train/cat.5550.jpg',
#  '/content/train/cat.9975.jpg',
#  '/content/train/cat.11753.jpg',
#  '/content/train/cat.12098.jpg',
#  '/content/train/cat.7931.jpg',
#  '/content/train/cat.7391.jpg',
#  '/content/train/cat.4611.jpg',
#  '/content/train/cat.12138.jpg',
#  '/content/train/dog.12364.jpg',
#  '/content/train/cat.3130.jpg',
#  '/content/train/cat.5003.jpg',
#  '/content/train/cat.8283.jpg',
#  '/content/train/cat.1672.jpg',
#  '/content/train/dog.5820.jpg',
#  '/content/train/dog.10205.jpg',
#  '/content/train/dog.4435.jpg',
#  '/content/train/dog.3521.jpg',
#  '/content/train/cat.9356.jpg',
#  '/content/train/cat.4192.jpg',
#  '/content/train/dog.2709.jpg',
#  '/content/train/cat.2220.jpg',
#  '/content/train/dog.3522.jpg',
#  '/content/train/dog.5990.jpg',
#  '/content/train/cat.5422.jpg',
#  '/content/train/cat.4325.jpg',
#  '/content/train/dog.2642.jpg',
#  '/content/train/cat.9842.jpg',
#  '/content/train/dog.2355.jpg',
#  '/content/train/cat.2552.jpg',
#  '/content/train/cat.6667.jpg',
#  '/content/train/cat.6435.jpg',
#  '/content/train/dog.9307.jpg',
#  '/content/train/dog.6862.jpg',
#  '/content/train/dog.5597.jpg',
#  '/content/train/dog.7072.jpg',
#  '/content/train/dog.2596.jpg',
#  '/content/train/dog.91.jpg',
#  '/content/train/dog.11368.jpg',
#  '/content/train/cat.1481.jpg',
#  '/content/train/dog.3505.jpg',
#  '/content/train/dog.12338.jpg',
#  '/content/train/cat.6356.jpg',
#  '/content/train/dog.5455.jpg',
#  '/content/train/cat.120.jpg',
#  '/content/train/dog.5580.jpg',
#  '/content/train/cat.7616.jpg',
#  '/content/train/cat.10359.jpg',
#  '/content/train/dog.5752.jpg',
#  '/content/train/dog.8223.jpg',
#  '/content/train/cat.4156.jpg',
#  '/content/train/cat.4307.jpg',
#  '/content/train/dog.5164.jpg',
#  '/content/train/cat.11699.jpg',
#  '/content/train/dog.8152.jpg',
#  '/content/train/cat.6758.jpg',
#  '/content/train/cat.9498.jpg',
#  '/content/train/cat.3492.jpg',
#  '/content/train/dog.6127.jpg',
#  '/content/train/dog.434.jpg',
#  '/content/train/cat.4108.jpg',
#  '/content/train/cat.10141.jpg',
#  '/content/train/dog.9034.jpg',
#  '/content/train/cat.11117.jpg',
#  '/content/train/cat.7736.jpg',
#  '/content/train/dog.11830.jpg',
#  '/content/train/dog.6586.jpg',
#  '/content/train/cat.4125.jpg',
#  '/content/train/cat.10263.jpg',
#  '/content/train/dog.7144.jpg',
#  '/content/train/dog.6799.jpg',
#  '/content/train/dog.948.jpg',
#  '/content/train/cat.4332.jpg',
#  '/content/train/dog.5333.jpg',
#  '/content/train/cat.1837.jpg',
#  '/content/train/dog.2448.jpg',
#  '/content/train/dog.5875.jpg',
#  '/content/train/dog.632.jpg',
#  '/content/train/cat.5818.jpg',
#  '/content/train/cat.5721.jpg',
#  '/content/train/cat.4786.jpg',
#  '/content/train/dog.10058.jpg',
#  '/content/train/dog.10678.jpg',
#  '/content/train/dog.10998.jpg',
#  '/content/train/cat.5279.jpg',
#  '/content/train/cat.210.jpg',
#  '/content/train/cat.7841.jpg',
#  '/content/train/dog.11113.jpg',
#  '/content/train/cat.8499.jpg',
#  '/content/train/dog.6534.jpg',
#  '/content/train/cat.7726.jpg',
#  '/content/train/cat.12468.jpg',
#  '/content/train/dog.1584.jpg',
#  '/content/train/dog.6777.jpg',
#  '/content/train/cat.10120.jpg',
#  '/content/train/cat.7797.jpg',
#  '/content/train/dog.7063.jpg',
#  '/content/train/dog.4403.jpg',
#  '/content/train/dog.11814.jpg',
#  '/content/train/cat.12459.jpg',
#  '/content/train/cat.6553.jpg',
#  '/content/train/dog.10582.jpg',
#  '/content/train/dog.417.jpg',
#  '/content/train/dog.1099.jpg',
#  '/content/train/dog.6779.jpg',
#  '/content/train/cat.695.jpg',
#  '/content/train/cat.8241.jpg',
#  '/content/train/cat.4378.jpg',
#  '/content/train/dog.11238.jpg',
#  '/content/train/cat.8145.jpg',
#  '/content/train/dog.1307.jpg',
#  '/content/train/cat.5483.jpg',
#  '/content/train/cat.771.jpg',
#  '/content/train/dog.2376.jpg',
#  '/content/train/dog.11028.jpg',
#  '/content/train/cat.1875.jpg',
#  '/content/train/dog.11141.jpg',
#  '/content/train/dog.6815.jpg',
#  '/content/train/cat.10577.jpg',
#  '/content/train/cat.11466.jpg',
#  '/content/train/cat.12305.jpg',
#  '/content/train/dog.9231.jpg',
#  '/content/train/cat.9797.jpg',
#  '/content/train/dog.1653.jpg',
#  '/content/train/dog.4118.jpg',
#  '/content/train/dog.4174.jpg',
#  '/content/train/dog.11117.jpg',
#  '/content/train/cat.5862.jpg',
#  '/content/train/dog.214.jpg',
#  '/content/train/dog.3823.jpg',
#  '/content/train/cat.8834.jpg',
#  '/content/train/dog.831.jpg',
#  '/content/train/dog.10553.jpg',
#  '/content/train/dog.11839.jpg',
#  '/content/train/cat.481.jpg',
#  '/content/train/cat.5211.jpg',
#  '/content/train/cat.7754.jpg',
#  '/content/train/dog.3762.jpg',
#  '/content/train/dog.5710.jpg',
#  '/content/train/dog.97.jpg',
#  '/content/train/cat.50.jpg',
#  '/content/train/dog.9751.jpg',
#  '/content/train/dog.10143.jpg',
#  '/content/train/cat.6076.jpg',
#  '/content/train/cat.7993.jpg',
#  '/content/train/cat.57.jpg',
#  '/content/train/dog.5517.jpg',
#  '/content/train/dog.3486.jpg',
#  '/content/train/cat.11745.jpg',
#  '/content/train/cat.9845.jpg',
#  '/content/train/cat.8296.jpg',
#  '/content/train/cat.12363.jpg',
#  '/content/train/cat.2742.jpg',
#  '/content/train/cat.1893.jpg',
#  '/content/train/cat.9795.jpg',
#  '/content/train/cat.3265.jpg',
#  '/content/train/cat.5624.jpg',
#  '/content/train/cat.9554.jpg',
#  '/content/train/dog.10824.jpg',
#  '/content/train/dog.7595.jpg',
#  '/content/train/dog.12315.jpg',
#  '/content/train/cat.6242.jpg',
#  '/content/train/dog.7808.jpg',
#  ...]

# %%
def copy_to_val_folder(val_list):
  val_path = "/content/val"
  for images in val_list:
    shutil.move(images,val_path)

# %%
def delete_train_test_folder(folder):
  for images in os.listdir("/content/".format(folder)):
      os.remove(os.path.join("/content/{}".format(folder) + "/" + images))
  os.removedirs("/content/".format(folder))

# %%
def empty_val_folder():
  for images in os.listdir(val_path):
    os.remove(os.path.join(val_path + "/" + images))

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                  horizontal_flip=True,
                                                                  validation_split=0.2)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_images = train_generator.flow_from_directory(
    directory="/content/train",
    
)
