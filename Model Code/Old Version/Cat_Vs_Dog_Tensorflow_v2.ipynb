# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.8.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 979 kB/s
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.5.0)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.37.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.34.1)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0.dev2021032900)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.34.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (57.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.5.0)
# Installing collected packages: tensorflowjs
# Successfully installed tensorflowjs-3.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import zipfile as zip
import glob
from sklearn.model_selection import train_test_split
import os as os
import shutil

# %%
zip_path = "/content/drive/MyDrive/Train-Test/"

# %%
with zip.ZipFile(zip_path + 'train.zip', 'r') as zipObj:
   zipObj.extractall()
  
with zip.ZipFile(zip_path + 'test1.zip', 'r') as zipObj:
   zipObj.extractall()

# %%
test_imgpath = "/content/test1/"
train_imgpath = "/content/train/"
val_imgpath = "/content/val/"

# %%
train_list = glob.glob(os.path.join(train_imgpath,'*.jpg'))
test_list = glob.glob(os.path.join(test_imgpath, '*.jpg'))

# %%
print(len(train_list),len(test_list))
# Out:
# 25000 12500

# %%
train_list, val_list = train_test_split(train_list, test_size=0.2,shuffle=True)

# %%
print(len(train_list),len(val_list))
# Out:
# 20000 5000

# %%
val_list
# Out:
# ['/content/train/dog.2444.jpg',
#  '/content/train/dog.1262.jpg',
#  '/content/train/dog.207.jpg',
#  '/content/train/cat.1429.jpg',
#  '/content/train/dog.90.jpg',
#  '/content/train/dog.8131.jpg',
#  '/content/train/cat.11383.jpg',
#  '/content/train/dog.7653.jpg',
#  '/content/train/cat.614.jpg',
#  '/content/train/cat.2115.jpg',
#  '/content/train/cat.11859.jpg',
#  '/content/train/dog.3721.jpg',
#  '/content/train/cat.1756.jpg',
#  '/content/train/cat.12414.jpg',
#  '/content/train/cat.2094.jpg',
#  '/content/train/cat.541.jpg',
#  '/content/train/dog.43.jpg',
#  '/content/train/cat.8737.jpg',
#  '/content/train/cat.7806.jpg',
#  '/content/train/dog.8181.jpg',
#  '/content/train/dog.11718.jpg',
#  '/content/train/dog.8780.jpg',
#  '/content/train/dog.9600.jpg',
#  '/content/train/dog.7482.jpg',
#  '/content/train/dog.12465.jpg',
#  '/content/train/dog.2368.jpg',
#  '/content/train/cat.6027.jpg',
#  '/content/train/cat.355.jpg',
#  '/content/train/dog.4401.jpg',
#  '/content/train/dog.8635.jpg',
#  '/content/train/dog.604.jpg',
#  '/content/train/dog.877.jpg',
#  '/content/train/cat.6550.jpg',
#  '/content/train/dog.3410.jpg',
#  '/content/train/cat.5418.jpg',
#  '/content/train/cat.5051.jpg',
#  '/content/train/dog.2376.jpg',
#  '/content/train/dog.10496.jpg',
#  '/content/train/cat.11303.jpg',
#  '/content/train/dog.9130.jpg',
#  '/content/train/dog.2107.jpg',
#  '/content/train/dog.9412.jpg',
#  '/content/train/dog.2583.jpg',
#  '/content/train/cat.8201.jpg',
#  '/content/train/dog.11421.jpg',
#  '/content/train/cat.5838.jpg',
#  '/content/train/cat.4494.jpg',
#  '/content/train/dog.9679.jpg',
#  '/content/train/cat.23.jpg',
#  '/content/train/dog.5843.jpg',
#  '/content/train/cat.6878.jpg',
#  '/content/train/dog.7556.jpg',
#  '/content/train/cat.1094.jpg',
#  '/content/train/cat.3067.jpg',
#  '/content/train/cat.1020.jpg',
#  '/content/train/dog.11537.jpg',
#  '/content/train/cat.3624.jpg',
#  '/content/train/dog.8056.jpg',
#  '/content/train/dog.3447.jpg',
#  '/content/train/dog.8755.jpg',
#  '/content/train/dog.8684.jpg',
#  '/content/train/dog.12329.jpg',
#  '/content/train/dog.2436.jpg',
#  '/content/train/cat.3505.jpg',
#  '/content/train/cat.1141.jpg',
#  '/content/train/cat.8969.jpg',
#  '/content/train/dog.2625.jpg',
#  '/content/train/cat.8958.jpg',
#  '/content/train/cat.1383.jpg',
#  '/content/train/dog.10744.jpg',
#  '/content/train/dog.10009.jpg',
#  '/content/train/cat.3082.jpg',
#  '/content/train/dog.1005.jpg',
#  '/content/train/dog.1435.jpg',
#  '/content/train/dog.3527.jpg',
#  '/content/train/cat.9004.jpg',
#  '/content/train/dog.11523.jpg',
#  '/content/train/dog.9537.jpg',
#  '/content/train/dog.8534.jpg',
#  '/content/train/cat.1314.jpg',
#  '/content/train/cat.3644.jpg',
#  '/content/train/cat.1492.jpg',
#  '/content/train/dog.8392.jpg',
#  '/content/train/cat.9601.jpg',
#  '/content/train/cat.4991.jpg',
#  '/content/train/cat.1349.jpg',
#  '/content/train/cat.3273.jpg',
#  '/content/train/cat.3676.jpg',
#  '/content/train/dog.5569.jpg',
#  '/content/train/cat.4834.jpg',
#  '/content/train/dog.328.jpg',
#  '/content/train/cat.5093.jpg',
#  '/content/train/cat.304.jpg',
#  '/content/train/cat.10630.jpg',
#  '/content/train/dog.9876.jpg',
#  '/content/train/cat.3699.jpg',
#  '/content/train/cat.6784.jpg',
#  '/content/train/cat.11353.jpg',
#  '/content/train/cat.129.jpg',
#  '/content/train/dog.3279.jpg',
#  '/content/train/cat.534.jpg',
#  '/content/train/cat.810.jpg',
#  '/content/train/cat.12030.jpg',
#  '/content/train/cat.9445.jpg',
#  '/content/train/cat.1786.jpg',
#  '/content/train/dog.808.jpg',
#  '/content/train/cat.968.jpg',
#  '/content/train/dog.3913.jpg',
#  '/content/train/dog.11332.jpg',
#  '/content/train/dog.1819.jpg',
#  '/content/train/dog.3707.jpg',
#  '/content/train/cat.7786.jpg',
#  '/content/train/cat.9667.jpg',
#  '/content/train/dog.4945.jpg',
#  '/content/train/dog.1421.jpg',
#  '/content/train/cat.3571.jpg',
#  '/content/train/cat.10709.jpg',
#  '/content/train/dog.9501.jpg',
#  '/content/train/cat.10506.jpg',
#  '/content/train/dog.2166.jpg',
#  '/content/train/cat.5156.jpg',
#  '/content/train/dog.1412.jpg',
#  '/content/train/cat.11499.jpg',
#  '/content/train/cat.422.jpg',
#  '/content/train/dog.2689.jpg',
#  '/content/train/dog.12150.jpg',
#  '/content/train/dog.8565.jpg',
#  '/content/train/dog.11814.jpg',
#  '/content/train/cat.9160.jpg',
#  '/content/train/cat.4576.jpg',
#  '/content/train/cat.2809.jpg',
#  '/content/train/dog.5948.jpg',
#  '/content/train/cat.5203.jpg',
#  '/content/train/cat.6570.jpg',
#  '/content/train/dog.3221.jpg',
#  '/content/train/cat.12489.jpg',
#  '/content/train/cat.12026.jpg',
#  '/content/train/cat.12141.jpg',
#  '/content/train/dog.4417.jpg',
#  '/content/train/dog.5986.jpg',
#  '/content/train/dog.422.jpg',
#  '/content/train/dog.4988.jpg',
#  '/content/train/cat.1046.jpg',
#  '/content/train/dog.7358.jpg',
#  '/content/train/cat.4656.jpg',
#  '/content/train/dog.12209.jpg',
#  '/content/train/dog.5063.jpg',
#  '/content/train/cat.7793.jpg',
#  '/content/train/dog.3722.jpg',
#  '/content/train/cat.7017.jpg',
#  '/content/train/cat.11935.jpg',
#  '/content/train/dog.8949.jpg',
#  '/content/train/dog.7419.jpg',
#  '/content/train/cat.7292.jpg',
#  '/content/train/cat.5640.jpg',
#  '/content/train/dog.6886.jpg',
#  '/content/train/dog.8177.jpg',
#  '/content/train/dog.5796.jpg',
#  '/content/train/dog.119.jpg',
#  '/content/train/dog.1636.jpg',
#  '/content/train/cat.432.jpg',
#  '/content/train/dog.1275.jpg',
#  '/content/train/dog.7907.jpg',
#  '/content/train/cat.2179.jpg',
#  '/content/train/dog.2690.jpg',
#  '/content/train/cat.9286.jpg',
#  '/content/train/cat.11034.jpg',
#  '/content/train/dog.4842.jpg',
#  '/content/train/cat.496.jpg',
#  '/content/train/cat.1662.jpg',
#  '/content/train/dog.1596.jpg',
#  '/content/train/dog.567.jpg',
#  '/content/train/cat.3042.jpg',
#  '/content/train/dog.12107.jpg',
#  '/content/train/dog.9789.jpg',
#  '/content/train/dog.2090.jpg',
#  '/content/train/cat.8810.jpg',
#  '/content/train/cat.7449.jpg',
#  '/content/train/dog.4797.jpg',
#  '/content/train/dog.3313.jpg',
#  '/content/train/dog.8164.jpg',
#  '/content/train/cat.8298.jpg',
#  '/content/train/cat.3411.jpg',
#  '/content/train/cat.10893.jpg',
#  '/content/train/dog.11664.jpg',
#  '/content/train/dog.625.jpg',
#  '/content/train/dog.6638.jpg',
#  '/content/train/dog.1959.jpg',
#  '/content/train/dog.10058.jpg',
#  '/content/train/cat.402.jpg',
#  '/content/train/cat.953.jpg',
#  '/content/train/dog.11682.jpg',
#  '/content/train/cat.11384.jpg',
#  '/content/train/dog.1374.jpg',
#  '/content/train/dog.1098.jpg',
#  '/content/train/dog.3050.jpg',
#  '/content/train/dog.8381.jpg',
#  '/content/train/cat.10130.jpg',
#  '/content/train/cat.12020.jpg',
#  '/content/train/cat.1446.jpg',
#  '/content/train/cat.11070.jpg',
#  '/content/train/dog.283.jpg',
#  '/content/train/cat.7075.jpg',
#  '/content/train/dog.1036.jpg',
#  '/content/train/dog.3095.jpg',
#  '/content/train/dog.6440.jpg',
#  '/content/train/dog.8623.jpg',
#  '/content/train/dog.4257.jpg',
#  '/content/train/dog.6015.jpg',
#  '/content/train/cat.3684.jpg',
#  '/content/train/cat.10491.jpg',
#  '/content/train/dog.1770.jpg',
#  '/content/train/cat.1836.jpg',
#  '/content/train/dog.9444.jpg',
#  '/content/train/cat.8413.jpg',
#  '/content/train/cat.3117.jpg',
#  '/content/train/dog.3972.jpg',
#  '/content/train/cat.35.jpg',
#  '/content/train/dog.5169.jpg',
#  '/content/train/dog.622.jpg',
#  '/content/train/cat.4838.jpg',
#  '/content/train/cat.9034.jpg',
#  '/content/train/cat.3252.jpg',
#  '/content/train/dog.1190.jpg',
#  '/content/train/dog.7641.jpg',
#  '/content/train/cat.10219.jpg',
#  '/content/train/cat.1675.jpg',
#  '/content/train/dog.5072.jpg',
#  '/content/train/dog.6211.jpg',
#  '/content/train/dog.10877.jpg',
#  '/content/train/cat.6662.jpg',
#  '/content/train/cat.4442.jpg',
#  '/content/train/dog.3539.jpg',
#  '/content/train/cat.5869.jpg',
#  '/content/train/dog.2404.jpg',
#  '/content/train/dog.10353.jpg',
#  '/content/train/cat.1775.jpg',
#  '/content/train/dog.7674.jpg',
#  '/content/train/dog.382.jpg',
#  '/content/train/cat.45.jpg',
#  '/content/train/dog.1977.jpg',
#  '/content/train/cat.10480.jpg',
#  '/content/train/dog.4622.jpg',
#  '/content/train/dog.205.jpg',
#  '/content/train/cat.9836.jpg',
#  '/content/train/cat.9573.jpg',
#  '/content/train/cat.10729.jpg',
#  '/content/train/cat.4588.jpg',
#  '/content/train/dog.6841.jpg',
#  '/content/train/cat.247.jpg',
#  '/content/train/dog.1406.jpg',
#  '/content/train/dog.9598.jpg',
#  '/content/train/cat.11652.jpg',
#  '/content/train/cat.5875.jpg',
#  '/content/train/dog.114.jpg',
#  '/content/train/dog.5933.jpg',
#  '/content/train/dog.11418.jpg',
#  '/content/train/cat.3695.jpg',
#  '/content/train/dog.9033.jpg',
#  '/content/train/dog.6703.jpg',
#  '/content/train/cat.7571.jpg',
#  '/content/train/dog.6640.jpg',
#  '/content/train/dog.8692.jpg',
#  '/content/train/dog.9472.jpg',
#  '/content/train/dog.6082.jpg',
#  '/content/train/dog.5052.jpg',
#  '/content/train/dog.1993.jpg',
#  '/content/train/cat.6284.jpg',
#  '/content/train/cat.10497.jpg',
#  '/content/train/cat.5566.jpg',
#  '/content/train/cat.11638.jpg',
#  '/content/train/dog.1472.jpg',
#  '/content/train/cat.11267.jpg',
#  '/content/train/dog.8020.jpg',
#  '/content/train/dog.848.jpg',
#  '/content/train/dog.8029.jpg',
#  '/content/train/dog.12069.jpg',
#  '/content/train/cat.6800.jpg',
#  '/content/train/cat.6456.jpg',
#  '/content/train/cat.6440.jpg',
#  '/content/train/dog.25.jpg',
#  '/content/train/cat.2220.jpg',
#  '/content/train/cat.11088.jpg',
#  '/content/train/cat.2422.jpg',
#  '/content/train/cat.1887.jpg',
#  '/content/train/dog.6775.jpg',
#  '/content/train/cat.9318.jpg',
#  '/content/train/dog.8175.jpg',
#  '/content/train/dog.6760.jpg',
#  '/content/train/cat.7199.jpg',
#  '/content/train/cat.2652.jpg',
#  '/content/train/cat.2677.jpg',
#  '/content/train/dog.11127.jpg',
#  '/content/train/cat.8867.jpg',
#  '/content/train/dog.7586.jpg',
#  '/content/train/dog.12490.jpg',
#  '/content/train/cat.6136.jpg',
#  '/content/train/dog.4935.jpg',
#  '/content/train/dog.2952.jpg',
#  '/content/train/dog.5117.jpg',
#  '/content/train/cat.4883.jpg',
#  '/content/train/dog.5955.jpg',
#  '/content/train/dog.2867.jpg',
#  '/content/train/dog.5500.jpg',
#  '/content/train/cat.5184.jpg',
#  '/content/train/cat.11391.jpg',
#  '/content/train/cat.997.jpg',
#  '/content/train/dog.9105.jpg',
#  '/content/train/cat.3550.jpg',
#  '/content/train/dog.4781.jpg',
#  '/content/train/dog.6164.jpg',
#  '/content/train/dog.11255.jpg',
#  '/content/train/cat.10355.jpg',
#  '/content/train/cat.9830.jpg',
#  '/content/train/dog.5253.jpg',
#  '/content/train/dog.9177.jpg',
#  '/content/train/cat.11286.jpg',
#  '/content/train/cat.179.jpg',
#  '/content/train/dog.6898.jpg',
#  '/content/train/dog.7259.jpg',
#  '/content/train/cat.1743.jpg',
#  '/content/train/cat.2010.jpg',
#  '/content/train/cat.11757.jpg',
#  '/content/train/dog.2236.jpg',
#  '/content/train/cat.7454.jpg',
#  '/content/train/cat.5147.jpg',
#  '/content/train/cat.2014.jpg',
#  '/content/train/dog.6059.jpg',
#  '/content/train/dog.3055.jpg',
#  '/content/train/cat.8677.jpg',
#  '/content/train/dog.4839.jpg',
#  '/content/train/dog.9420.jpg',
#  '/content/train/dog.3204.jpg',
#  '/content/train/dog.1078.jpg',
#  '/content/train/cat.10641.jpg',
#  '/content/train/cat.11220.jpg',
#  '/content/train/cat.3563.jpg',
#  '/content/train/cat.7157.jpg',
#  '/content/train/cat.4697.jpg',
#  '/content/train/cat.1154.jpg',
#  '/content/train/cat.4175.jpg',
#  '/content/train/dog.11576.jpg',
#  '/content/train/cat.1643.jpg',
#  '/content/train/cat.5294.jpg',
#  '/content/train/dog.979.jpg',
#  '/content/train/dog.250.jpg',
#  '/content/train/dog.7281.jpg',
#  '/content/train/cat.7101.jpg',
#  '/content/train/dog.10819.jpg',
#  '/content/train/dog.11906.jpg',
#  '/content/train/dog.1967.jpg',
#  '/content/train/cat.1820.jpg',
#  '/content/train/dog.295.jpg',
#  '/content/train/dog.732.jpg',
#  '/content/train/cat.10432.jpg',
#  '/content/train/dog.4061.jpg',
#  '/content/train/dog.10472.jpg',
#  '/content/train/cat.1286.jpg',
#  '/content/train/cat.3169.jpg',
#  '/content/train/dog.3582.jpg',
#  '/content/train/cat.9420.jpg',
#  '/content/train/cat.11488.jpg',
#  '/content/train/cat.2711.jpg',
#  '/content/train/cat.7731.jpg',
#  '/content/train/dog.12026.jpg',
#  '/content/train/dog.5977.jpg',
#  '/content/train/cat.4088.jpg',
#  '/content/train/cat.3064.jpg',
#  '/content/train/dog.4937.jpg',
#  '/content/train/dog.12297.jpg',
#  '/content/train/cat.7191.jpg',
#  '/content/train/dog.9798.jpg',
#  '/content/train/cat.9494.jpg',
#  '/content/train/cat.12213.jpg',
#  '/content/train/dog.6937.jpg',
#  '/content/train/cat.1110.jpg',
#  '/content/train/dog.271.jpg',
#  '/content/train/dog.1087.jpg',
#  '/content/train/cat.732.jpg',
#  '/content/train/cat.2439.jpg',
#  '/content/train/cat.3072.jpg',
#  '/content/train/cat.2066.jpg',
#  '/content/train/cat.6026.jpg',
#  '/content/train/dog.6308.jpg',
#  '/content/train/dog.8207.jpg',
#  '/content/train/cat.6811.jpg',
#  '/content/train/cat.5437.jpg',
#  '/content/train/dog.6017.jpg',
#  '/content/train/dog.11164.jpg',
#  '/content/train/dog.5315.jpg',
#  '/content/train/cat.9206.jpg',
#  '/content/train/dog.6515.jpg',
#  '/content/train/dog.322.jpg',
#  '/content/train/cat.8445.jpg',
#  '/content/train/dog.4827.jpg',
#  '/content/train/dog.12341.jpg',
#  '/content/train/cat.3191.jpg',
#  '/content/train/cat.9776.jpg',
#  '/content/train/dog.7546.jpg',
#  '/content/train/dog.2479.jpg',
#  '/content/train/dog.6312.jpg',
#  '/content/train/dog.4507.jpg',
#  '/content/train/dog.143.jpg',
#  '/content/train/cat.5237.jpg',
#  '/content/train/dog.4262.jpg',
#  '/content/train/cat.9879.jpg',
#  '/content/train/cat.7139.jpg',
#  '/content/train/cat.9047.jpg',
#  '/content/train/cat.6166.jpg',
#  '/content/train/dog.11233.jpg',
#  '/content/train/dog.6099.jpg',
#  '/content/train/cat.8063.jpg',
#  '/content/train/cat.8293.jpg',
#  '/content/train/dog.238.jpg',
#  '/content/train/cat.11908.jpg',
#  '/content/train/cat.7405.jpg',
#  '/content/train/dog.2128.jpg',
#  '/content/train/cat.10976.jpg',
#  '/content/train/cat.6687.jpg',
#  '/content/train/dog.5350.jpg',
#  '/content/train/cat.2942.jpg',
#  '/content/train/dog.5743.jpg',
#  '/content/train/dog.11962.jpg',
#  '/content/train/dog.577.jpg',
#  '/content/train/cat.8836.jpg',
#  '/content/train/cat.2947.jpg',
#  '/content/train/cat.7556.jpg',
#  '/content/train/cat.9195.jpg',
#  '/content/train/dog.5693.jpg',
#  '/content/train/dog.7941.jpg',
#  '/content/train/cat.6885.jpg',
#  '/content/train/dog.3019.jpg',
#  '/content/train/dog.10695.jpg',
#  '/content/train/dog.8854.jpg',
#  '/content/train/cat.9254.jpg',
#  '/content/train/dog.10605.jpg',
#  '/content/train/dog.2191.jpg',
#  '/content/train/dog.3114.jpg',
#  '/content/train/cat.8880.jpg',
#  '/content/train/cat.3262.jpg',
#  '/content/train/cat.4069.jpg',
#  '/content/train/cat.3733.jpg',
#  '/content/train/cat.11149.jpg',
#  '/content/train/cat.7254.jpg',
#  '/content/train/cat.5162.jpg',
#  '/content/train/dog.6222.jpg',
#  '/content/train/dog.9494.jpg',
#  '/content/train/dog.5177.jpg',
#  '/content/train/dog.3284.jpg',
#  '/content/train/dog.3370.jpg',
#  '/content/train/dog.4204.jpg',
#  '/content/train/cat.2979.jpg',
#  '/content/train/cat.12400.jpg',
#  '/content/train/cat.6449.jpg',
#  '/content/train/dog.8765.jpg',
#  '/content/train/cat.624.jpg',
#  '/content/train/dog.1415.jpg',
#  '/content/train/dog.9817.jpg',
#  '/content/train/dog.9928.jpg',
#  '/content/train/dog.6857.jpg',
#  '/content/train/cat.9100.jpg',
#  '/content/train/dog.9921.jpg',
#  '/content/train/cat.5233.jpg',
#  '/content/train/dog.2786.jpg',
#  '/content/train/dog.11390.jpg',
#  '/content/train/cat.8008.jpg',
#  '/content/train/cat.10415.jpg',
#  '/content/train/dog.4456.jpg',
#  '/content/train/cat.1725.jpg',
#  '/content/train/cat.5019.jpg',
#  '/content/train/dog.10409.jpg',
#  '/content/train/dog.12218.jpg',
#  '/content/train/dog.983.jpg',
#  '/content/train/cat.5489.jpg',
#  '/content/train/cat.1130.jpg',
#  '/content/train/cat.5075.jpg',
#  '/content/train/dog.2281.jpg',
#  '/content/train/cat.3718.jpg',
#  '/content/train/dog.5494.jpg',
#  '/content/train/dog.1638.jpg',
#  '/content/train/cat.6002.jpg',
#  '/content/train/dog.4590.jpg',
#  '/content/train/dog.11636.jpg',
#  '/content/train/dog.4660.jpg',
#  '/content/train/dog.3994.jpg',
#  '/content/train/cat.4401.jpg',
#  '/content/train/cat.1374.jpg',
#  '/content/train/dog.3578.jpg',
#  '/content/train/cat.9269.jpg',
#  '/content/train/cat.7186.jpg',
#  '/content/train/dog.8178.jpg',
#  '/content/train/cat.11689.jpg',
#  '/content/train/cat.5880.jpg',
#  '/content/train/cat.12113.jpg',
#  '/content/train/dog.7449.jpg',
#  '/content/train/cat.4797.jpg',
#  '/content/train/cat.10200.jpg',
#  '/content/train/cat.10588.jpg',
#  '/content/train/cat.7227.jpg',
#  '/content/train/cat.10229.jpg',
#  '/content/train/dog.463.jpg',
#  '/content/train/cat.6590.jpg',
#  '/content/train/cat.4868.jpg',
#  '/content/train/dog.6806.jpg',
#  '/content/train/cat.8316.jpg',
#  '/content/train/cat.4050.jpg',
#  '/content/train/cat.5020.jpg',
#  '/content/train/cat.8442.jpg',
#  '/content/train/dog.4505.jpg',
#  '/content/train/dog.3295.jpg',
#  '/content/train/cat.5304.jpg',
#  '/content/train/dog.12216.jpg',
#  '/content/train/cat.6461.jpg',
#  '/content/train/cat.1878.jpg',
#  '/content/train/cat.3036.jpg',
#  '/content/train/dog.7579.jpg',
#  '/content/train/dog.3229.jpg',
#  '/content/train/dog.5468.jpg',
#  '/content/train/cat.7238.jpg',
#  '/content/train/dog.9914.jpg',
#  '/content/train/dog.2125.jpg',
#  '/content/train/cat.9941.jpg',
#  '/content/train/cat.6011.jpg',
#  '/content/train/cat.8727.jpg',
#  '/content/train/dog.4177.jpg',
#  '/content/train/dog.9609.jpg',
#  '/content/train/cat.1.jpg',
#  '/content/train/dog.460.jpg',
#  '/content/train/dog.4699.jpg',
#  '/content/train/dog.547.jpg',
#  '/content/train/dog.11001.jpg',
#  '/content/train/dog.7610.jpg',
#  '/content/train/dog.4219.jpg',
#  '/content/train/cat.12430.jpg',
#  '/content/train/cat.1354.jpg',
#  '/content/train/cat.10977.jpg',
#  '/content/train/cat.6010.jpg',
#  '/content/train/cat.8414.jpg',
#  '/content/train/cat.4108.jpg',
#  '/content/train/dog.6785.jpg',
#  '/content/train/cat.8389.jpg',
#  '/content/train/dog.5453.jpg',
#  '/content/train/cat.11182.jpg',
#  '/content/train/dog.8407.jpg',
#  '/content/train/dog.12021.jpg',
#  '/content/train/cat.4953.jpg',
#  '/content/train/dog.7688.jpg',
#  '/content/train/cat.1653.jpg',
#  '/content/train/dog.10847.jpg',
#  '/content/train/dog.3556.jpg',
#  '/content/train/dog.906.jpg',
#  '/content/train/cat.11084.jpg',
#  '/content/train/cat.6576.jpg',
#  '/content/train/cat.7561.jpg',
#  '/content/train/dog.7825.jpg',
#  '/content/train/dog.11321.jpg',
#  '/content/train/dog.4542.jpg',
#  '/content/train/cat.8855.jpg',
#  '/content/train/cat.3696.jpg',
#  '/content/train/dog.11198.jpg',
#  '/content/train/cat.2389.jpg',
#  '/content/train/dog.5303.jpg',
#  '/content/train/dog.10772.jpg',
#  '/content/train/cat.4784.jpg',
#  '/content/train/cat.715.jpg',
#  '/content/train/cat.5408.jpg',
#  '/content/train/cat.5724.jpg',
#  '/content/train/cat.11532.jpg',
#  '/content/train/dog.7716.jpg',
#  '/content/train/cat.24.jpg',
#  '/content/train/cat.8842.jpg',
#  '/content/train/dog.6444.jpg',
#  '/content/train/dog.3339.jpg',
#  '/content/train/cat.2533.jpg',
#  '/content/train/cat.4549.jpg',
#  '/content/train/cat.10125.jpg',
#  '/content/train/cat.1313.jpg',
#  '/content/train/cat.9711.jpg',
#  '/content/train/cat.249.jpg',
#  '/content/train/dog.5635.jpg',
#  '/content/train/dog.9497.jpg',
#  '/content/train/dog.8892.jpg',
#  '/content/train/dog.1274.jpg',
#  '/content/train/dog.1755.jpg',
#  '/content/train/dog.5816.jpg',
#  '/content/train/dog.1903.jpg',
#  '/content/train/cat.632.jpg',
#  '/content/train/cat.7977.jpg',
#  '/content/train/dog.4520.jpg',
#  '/content/train/cat.12291.jpg',
#  '/content/train/cat.10947.jpg',
#  '/content/train/cat.10374.jpg',
#  '/content/train/dog.3588.jpg',
#  '/content/train/dog.6959.jpg',
#  '/content/train/cat.9518.jpg',
#  '/content/train/cat.8608.jpg',
#  '/content/train/dog.1633.jpg',
#  '/content/train/dog.4763.jpg',
#  '/content/train/dog.9007.jpg',
#  '/content/train/cat.894.jpg',
#  '/content/train/dog.11050.jpg',
#  '/content/train/cat.1915.jpg',
#  '/content/train/dog.5146.jpg',
#  '/content/train/cat.9856.jpg',
#  '/content/train/dog.7514.jpg',
#  '/content/train/cat.2073.jpg',
#  '/content/train/dog.5223.jpg',
#  '/content/train/dog.8597.jpg',
#  '/content/train/dog.4595.jpg',
#  '/content/train/dog.7082.jpg',
#  '/content/train/cat.9292.jpg',
#  '/content/train/dog.6669.jpg',
#  '/content/train/cat.12041.jpg',
#  '/content/train/cat.2123.jpg',
#  '/content/train/cat.7041.jpg',
#  '/content/train/cat.2302.jpg',
#  '/content/train/cat.7251.jpg',
#  '/content/train/cat.1367.jpg',
#  '/content/train/dog.769.jpg',
#  '/content/train/dog.6585.jpg',
#  '/content/train/dog.2939.jpg',
#  '/content/train/cat.7150.jpg',
#  '/content/train/cat.3482.jpg',
#  '/content/train/dog.9461.jpg',
#  '/content/train/cat.8833.jpg',
#  '/content/train/dog.8832.jpg',
#  '/content/train/cat.11801.jpg',
#  '/content/train/dog.13.jpg',
#  '/content/train/dog.2410.jpg',
#  '/content/train/cat.10320.jpg',
#  '/content/train/cat.6952.jpg',
#  '/content/train/cat.10684.jpg',
#  '/content/train/dog.3586.jpg',
#  '/content/train/cat.4179.jpg',
#  '/content/train/cat.3403.jpg',
#  '/content/train/cat.2619.jpg',
#  '/content/train/cat.2072.jpg',
#  '/content/train/dog.4344.jpg',
#  '/content/train/dog.8022.jpg',
#  '/content/train/dog.11387.jpg',
#  '/content/train/dog.6134.jpg',
#  '/content/train/cat.7120.jpg',
#  '/content/train/dog.2803.jpg',
#  '/content/train/cat.8037.jpg',
#  '/content/train/dog.10567.jpg',
#  '/content/train/dog.10964.jpg',
#  '/content/train/cat.3628.jpg',
#  '/content/train/dog.6304.jpg',
#  '/content/train/dog.3868.jpg',
#  '/content/train/cat.5350.jpg',
#  '/content/train/dog.4482.jpg',
#  '/content/train/cat.10106.jpg',
#  '/content/train/cat.2126.jpg',
#  '/content/train/cat.2558.jpg',
#  '/content/train/cat.6469.jpg',
#  '/content/train/cat.456.jpg',
#  '/content/train/dog.4783.jpg',
#  '/content/train/cat.11402.jpg',
#  '/content/train/dog.8908.jpg',
#  '/content/train/cat.4582.jpg',
#  '/content/train/cat.9343.jpg',
#  '/content/train/dog.2736.jpg',
#  '/content/train/cat.1978.jpg',
#  '/content/train/cat.5589.jpg',
#  '/content/train/cat.454.jpg',
#  '/content/train/dog.8890.jpg',
#  '/content/train/cat.10714.jpg',
#  '/content/train/cat.3710.jpg',
#  '/content/train/dog.3635.jpg',
#  '/content/train/cat.625.jpg',
#  '/content/train/dog.3022.jpg',
#  '/content/train/dog.1120.jpg',
#  '/content/train/cat.11879.jpg',
#  '/content/train/dog.2813.jpg',
#  '/content/train/cat.942.jpg',
#  '/content/train/dog.1378.jpg',
#  '/content/train/cat.4.jpg',
#  '/content/train/cat.4080.jpg',
#  '/content/train/dog.4001.jpg',
#  '/content/train/cat.7924.jpg',
#  '/content/train/cat.4275.jpg',
#  '/content/train/dog.1833.jpg',
#  '/content/train/cat.2351.jpg',
#  '/content/train/cat.7248.jpg',
#  '/content/train/dog.4301.jpg',
#  '/content/train/cat.9852.jpg',
#  '/content/train/cat.3519.jpg',
#  '/content/train/cat.5883.jpg',
#  '/content/train/cat.11755.jpg',
#  '/content/train/dog.5485.jpg',
#  '/content/train/cat.697.jpg',
#  '/content/train/dog.5024.jpg',
#  '/content/train/dog.1556.jpg',
#  '/content/train/dog.1058.jpg',
#  '/content/train/dog.1149.jpg',
#  '/content/train/cat.543.jpg',
#  '/content/train/cat.549.jpg',
#  '/content/train/dog.8067.jpg',
#  '/content/train/dog.3239.jpg',
#  '/content/train/cat.8235.jpg',
#  '/content/train/cat.7338.jpg',
#  '/content/train/dog.3430.jpg',
#  '/content/train/dog.10434.jpg',
#  '/content/train/dog.2613.jpg',
#  '/content/train/cat.389.jpg',
#  '/content/train/cat.5864.jpg',
#  '/content/train/cat.11821.jpg',
#  '/content/train/cat.6122.jpg',
#  '/content/train/dog.6087.jpg',
#  '/content/train/cat.8209.jpg',
#  '/content/train/cat.8215.jpg',
#  '/content/train/cat.5587.jpg',
#  '/content/train/dog.142.jpg',
#  '/content/train/cat.10922.jpg',
#  '/content/train/dog.7372.jpg',
#  '/content/train/dog.9848.jpg',
#  '/content/train/cat.504.jpg',
#  '/content/train/dog.6231.jpg',
#  '/content/train/cat.5978.jpg',
#  '/content/train/cat.8043.jpg',
#  '/content/train/dog.5220.jpg',
#  '/content/train/cat.3376.jpg',
#  '/content/train/dog.7226.jpg',
#  '/content/train/dog.2059.jpg',
#  '/content/train/dog.10740.jpg',
#  '/content/train/dog.8435.jpg',
#  '/content/train/cat.12134.jpg',
#  '/content/train/cat.2237.jpg',
#  '/content/train/cat.4680.jpg',
#  '/content/train/cat.3385.jpg',
#  '/content/train/cat.6615.jpg',
#  '/content/train/cat.9197.jpg',
#  '/content/train/cat.587.jpg',
#  '/content/train/dog.7339.jpg',
#  '/content/train/cat.12480.jpg',
#  '/content/train/dog.2480.jpg',
#  '/content/train/cat.3568.jpg',
#  '/content/train/dog.1880.jpg',
#  '/content/train/dog.10272.jpg',
#  '/content/train/cat.5436.jpg',
#  '/content/train/cat.6820.jpg',
#  '/content/train/cat.4553.jpg',
#  '/content/train/cat.8970.jpg',
#  '/content/train/cat.10966.jpg',
#  '/content/train/dog.9390.jpg',
#  '/content/train/dog.816.jpg',
#  '/content/train/dog.11516.jpg',
#  '/content/train/cat.3996.jpg',
#  '/content/train/dog.2510.jpg',
#  '/content/train/dog.3592.jpg',
#  '/content/train/cat.7256.jpg',
#  '/content/train/dog.5167.jpg',
#  '/content/train/cat.2122.jpg',
#  '/content/train/cat.10368.jpg',
#  '/content/train/dog.4737.jpg',
#  '/content/train/dog.893.jpg',
#  '/content/train/dog.11196.jpg',
#  '/content/train/cat.339.jpg',
#  '/content/train/cat.8443.jpg',
#  '/content/train/dog.5633.jpg',
#  '/content/train/cat.11210.jpg',
#  '/content/train/cat.744.jpg',
#  '/content/train/cat.1666.jpg',
#  '/content/train/cat.1461.jpg',
#  '/content/train/dog.7413.jpg',
#  '/content/train/dog.8840.jpg',
#  '/content/train/dog.8614.jpg',
#  '/content/train/cat.3935.jpg',
#  '/content/train/cat.2132.jpg',
#  '/content/train/cat.5390.jpg',
#  '/content/train/cat.2796.jpg',
#  '/content/train/dog.7177.jpg',
#  '/content/train/cat.3116.jpg',
#  '/content/train/cat.7371.jpg',
#  '/content/train/cat.10068.jpg',
#  '/content/train/cat.4059.jpg',
#  '/content/train/cat.656.jpg',
#  '/content/train/cat.1655.jpg',
#  '/content/train/dog.8356.jpg',
#  '/content/train/dog.1489.jpg',
#  '/content/train/cat.4230.jpg',
#  '/content/train/cat.6984.jpg',
#  '/content/train/cat.6602.jpg',
#  '/content/train/dog.6496.jpg',
#  '/content/train/dog.84.jpg',
#  '/content/train/cat.3517.jpg',
#  '/content/train/dog.6957.jpg',
#  '/content/train/cat.10357.jpg',
#  '/content/train/cat.5814.jpg',
#  '/content/train/cat.4505.jpg',
#  '/content/train/dog.5226.jpg',
#  '/content/train/cat.149.jpg',
#  '/content/train/dog.316.jpg',
#  '/content/train/dog.3743.jpg',
#  '/content/train/dog.2321.jpg',
#  '/content/train/cat.8313.jpg',
#  '/content/train/cat.3201.jpg',
#  '/content/train/cat.7690.jpg',
#  '/content/train/cat.5204.jpg',
#  '/content/train/dog.8231.jpg',
#  '/content/train/cat.5529.jpg',
#  '/content/train/dog.6729.jpg',
#  '/content/train/dog.883.jpg',
#  '/content/train/dog.5919.jpg',
#  '/content/train/dog.11945.jpg',
#  '/content/train/dog.3547.jpg',
#  '/content/train/cat.3683.jpg',
#  '/content/train/dog.5272.jpg',
#  '/content/train/dog.11227.jpg',
#  '/content/train/dog.10940.jpg',
#  '/content/train/dog.412.jpg',
#  '/content/train/cat.5656.jpg',
#  '/content/train/cat.10551.jpg',
#  '/content/train/dog.4600.jpg',
#  '/content/train/dog.8129.jpg',
#  '/content/train/dog.7533.jpg',
#  '/content/train/cat.2036.jpg',
#  '/content/train/dog.372.jpg',
#  '/content/train/dog.9747.jpg',
#  '/content/train/dog.7867.jpg',
#  '/content/train/cat.9280.jpg',
#  '/content/train/dog.7683.jpg',
#  '/content/train/dog.9247.jpg',
#  '/content/train/dog.7884.jpg',
#  '/content/train/cat.7293.jpg',
#  '/content/train/dog.8851.jpg',
#  '/content/train/cat.10450.jpg',
#  '/content/train/cat.1165.jpg',
#  '/content/train/dog.1721.jpg',
#  '/content/train/cat.3620.jpg',
#  '/content/train/cat.439.jpg',
#  '/content/train/dog.8328.jpg',
#  '/content/train/cat.7177.jpg',
#  '/content/train/dog.3818.jpg',
#  '/content/train/cat.5002.jpg',
#  '/content/train/dog.315.jpg',
#  '/content/train/dog.4338.jpg',
#  '/content/train/cat.1618.jpg',
#  '/content/train/cat.10021.jpg',
#  '/content/train/cat.9534.jpg',
#  '/content/train/dog.5789.jpg',
#  '/content/train/cat.4139.jpg',
#  '/content/train/dog.10169.jpg',
#  '/content/train/cat.571.jpg',
#  '/content/train/dog.12226.jpg',
#  '/content/train/dog.226.jpg',
#  '/content/train/dog.8658.jpg',
#  '/content/train/cat.10620.jpg',
#  '/content/train/cat.2645.jpg',
#  '/content/train/dog.5861.jpg',
#  '/content/train/dog.1844.jpg',
#  '/content/train/dog.10650.jpg',
#  '/content/train/dog.821.jpg',
#  '/content/train/cat.2277.jpg',
#  '/content/train/cat.7982.jpg',
#  '/content/train/dog.7822.jpg',
#  '/content/train/dog.11340.jpg',
#  '/content/train/cat.5417.jpg',
#  '/content/train/cat.7127.jpg',
#  '/content/train/dog.7950.jpg',
#  '/content/train/dog.11393.jpg',
#  '/content/train/dog.1889.jpg',
#  '/content/train/cat.307.jpg',
#  '/content/train/cat.1906.jpg',
#  '/content/train/dog.6639.jpg',
#  '/content/train/dog.3011.jpg',
#  '/content/train/dog.4602.jpg',
#  '/content/train/dog.2645.jpg',
#  '/content/train/cat.1737.jpg',
#  '/content/train/cat.9112.jpg',
#  '/content/train/cat.7287.jpg',
#  '/content/train/dog.6956.jpg',
#  '/content/train/dog.4062.jpg',
#  '/content/train/cat.2777.jpg',
#  '/content/train/cat.2876.jpg',
#  '/content/train/cat.3982.jpg',
#  '/content/train/dog.5205.jpg',
#  '/content/train/cat.11760.jpg',
#  '/content/train/cat.795.jpg',
#  '/content/train/cat.6672.jpg',
#  '/content/train/dog.10737.jpg',
#  '/content/train/cat.2907.jpg',
#  '/content/train/cat.9913.jpg',
#  '/content/train/cat.4235.jpg',
#  '/content/train/dog.8037.jpg',
#  '/content/train/dog.8471.jpg',
#  '/content/train/dog.9287.jpg',
#  '/content/train/cat.7675.jpg',
#  '/content/train/cat.9525.jpg',
#  '/content/train/cat.3395.jpg',
#  '/content/train/dog.3170.jpg',
#  '/content/train/cat.1159.jpg',
#  '/content/train/cat.3582.jpg',
#  '/content/train/dog.11004.jpg',
#  '/content/train/dog.10411.jpg',
#  '/content/train/cat.12016.jpg',
#  '/content/train/cat.8481.jpg',
#  '/content/train/cat.5912.jpg',
#  '/content/train/dog.7444.jpg',
#  '/content/train/cat.4674.jpg',
#  '/content/train/dog.5641.jpg',
#  '/content/train/dog.11749.jpg',
#  '/content/train/cat.5733.jpg',
#  '/content/train/cat.7258.jpg',
#  '/content/train/dog.2244.jpg',
#  '/content/train/cat.10111.jpg',
#  '/content/train/cat.6882.jpg',
#  '/content/train/cat.4891.jpg',
#  '/content/train/cat.11811.jpg',
#  '/content/train/cat.3351.jpg',
#  '/content/train/dog.3866.jpg',
#  '/content/train/dog.3016.jpg',
#  '/content/train/dog.9293.jpg',
#  '/content/train/cat.5040.jpg',
#  '/content/train/dog.6187.jpg',
#  '/content/train/dog.6506.jpg',
#  '/content/train/cat.10939.jpg',
#  '/content/train/dog.1969.jpg',
#  '/content/train/dog.7124.jpg',
#  '/content/train/cat.3547.jpg',
#  '/content/train/dog.3606.jpg',
#  '/content/train/dog.8212.jpg',
#  '/content/train/cat.10664.jpg',
#  '/content/train/dog.12062.jpg',
#  '/content/train/cat.6444.jpg',
#  '/content/train/cat.1768.jpg',
#  '/content/train/dog.6873.jpg',
#  '/content/train/dog.4015.jpg',
#  '/content/train/dog.12325.jpg',
#  '/content/train/dog.1709.jpg',
#  '/content/train/dog.3666.jpg',
#  '/content/train/cat.1564.jpg',
#  '/content/train/cat.8185.jpg',
#  '/content/train/cat.11421.jpg',
#  '/content/train/cat.8865.jpg',
#  '/content/train/cat.9226.jpg',
#  '/content/train/dog.7396.jpg',
#  '/content/train/cat.3044.jpg',
#  '/content/train/dog.2957.jpg',
#  '/content/train/cat.7099.jpg',
#  '/content/train/dog.9801.jpg',
#  '/content/train/dog.7057.jpg',
#  '/content/train/cat.5602.jpg',
#  '/content/train/dog.7561.jpg',
#  '/content/train/cat.6335.jpg',
#  '/content/train/dog.5876.jpg',
#  '/content/train/cat.7864.jpg',
#  '/content/train/cat.8175.jpg',
#  '/content/train/dog.11565.jpg',
#  '/content/train/cat.10295.jpg',
#  '/content/train/cat.11473.jpg',
#  '/content/train/dog.6464.jpg',
#  '/content/train/cat.9261.jpg',
#  '/content/train/cat.8258.jpg',
#  '/content/train/cat.2456.jpg',
#  '/content/train/cat.9259.jpg',
#  '/content/train/cat.7967.jpg',
#  '/content/train/dog.5122.jpg',
#  '/content/train/cat.11837.jpg',
#  '/content/train/cat.2603.jpg',
#  '/content/train/dog.6459.jpg',
#  '/content/train/dog.12305.jpg',
#  '/content/train/dog.7398.jpg',
#  '/content/train/dog.1059.jpg',
#  '/content/train/dog.4280.jpg',
#  '/content/train/cat.11961.jpg',
#  '/content/train/dog.1522.jpg',
#  '/content/train/dog.10436.jpg',
#  '/content/train/dog.12424.jpg',
#  '/content/train/dog.4643.jpg',
#  '/content/train/dog.3383.jpg',
#  '/content/train/dog.7352.jpg',
#  '/content/train/dog.9069.jpg',
#  '/content/train/dog.9918.jpg',
#  '/content/train/cat.5059.jpg',
#  '/content/train/cat.5706.jpg',
#  '/content/train/cat.649.jpg',
#  '/content/train/dog.4861.jpg',
#  '/content/train/cat.2314.jpg',
#  '/content/train/cat.7937.jpg',
#  '/content/train/cat.9367.jpg',
#  '/content/train/cat.12344.jpg',
#  '/content/train/dog.1750.jpg',
#  '/content/train/cat.660.jpg',
#  '/content/train/dog.930.jpg',
#  '/content/train/cat.5701.jpg',
#  '/content/train/cat.3460.jpg',
#  '/content/train/cat.6893.jpg',
#  '/content/train/dog.9386.jpg',
#  '/content/train/cat.113.jpg',
#  '/content/train/dog.1542.jpg',
#  '/content/train/cat.1639.jpg',
#  '/content/train/cat.3417.jpg',
#  '/content/train/cat.944.jpg',
#  '/content/train/cat.3179.jpg',
#  '/content/train/dog.11777.jpg',
#  '/content/train/dog.4818.jpg',
#  '/content/train/dog.9338.jpg',
#  '/content/train/cat.9912.jpg',
#  '/content/train/dog.3767.jpg',
#  ...]

# %%
def copy_to_val_folder(val_list):
  val_path = "/content/val"
  for images in val_list:
    shutil.move(images,val_path)

# %%
def delete_train_test_folder(folder):
  for images in os.listdir("/content/".format(folder)):
      os.remove(os.path.join("/content/{}".format(folder) + "/" + images))
  os.removedirs("/content/".format(folder))

# %%
def empty_val_folder():
  for images in os.listdir(val_path):
    os.remove(os.path.join(val_path + "/" + images))

# %%
copy_to_val_folder(val_list)

# %%
def align_train_data():
  os.mkdir(train_imgpath + "dog")
  os.mkdir(train_imgpath + "cat")

  for image in os.listdir(train_imgpath):
    if image.split(".")[0] == "dog":
      shutil.move(train_imgpath + image,train_imgpath + "dog")
    else:
      shutil.move(train_imgpath + image,train_imgpath + "cat")

align_train_data()

# %%
def align_val_data():
  os.mkdir(val_imgpath + "dog")
  os.mkdir(val_imgpath + "cat")

  for image in os.listdir(val_imgpath):
    if image.split(".")[0] == "dog":
      shutil.move(val_imgpath + image,val_imgpath + "dog")
    else:
      shutil.move(val_imgpath + image,val_imgpath + "cat")

align_val_data()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                  horizontal_flip=True,
                                                                  validation_split=0.2)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_images = train_generator.flow_from_directory(
    directory = train_imgpath,
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=100,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_directory(
    directory=val_imgpath,
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=100,
    shuffle=True,
    seed=42,
    subset='validation'
)
# Out:
# Found 16001 images belonging to 2 classes.
# Found 999 images belonging to 2 classes.
